# %% [markdown]
# ## Week 2 Homework

# %%
#1.

name = "Clare"
age = 20
Grade = 100.0
is_student = True
favorite_color = "green"

print(name)
print(age)
print(Grade)
print(is_student)
print(favorite_color)
# Out:
# Clare
# 20
# 100.0
# True
# green

# %%
#2.

name: str = "Clare"
age: int = 20
grade: float = 100.0
is_student: bool = True
favorite_color: str = "green"

# %%
#3.

name = name.upper()
print(name)
# Out:
# CLARE

# %%
#4.

result = age + grade #an int and a float added makes a float.
print(type(result))
# Out:
# <class 'float'>

# %%
#5.

person = {"name": name, "age": age, "grade": grade, "is_student": is_student, "favorite_color": favorite_color}
person
# Out:
# {'name': 'CLARE',
#  'age': 20,
#  'grade': 100.0,
#  'is_student': True,
#  'favorite_color': 'green'}

# %%
#6.

print(f"My name is {person['name']}. I am {person['age']} years old. My favorite color is {person['favorite_color']}. I will get a {person['grade']} in this class.")
# Out:
# My name is CLARE. I am 20 years old. My favorite color is green. I will get a 100.0 in this class.
